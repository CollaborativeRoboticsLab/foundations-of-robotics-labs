# %% [markdown]
# # Terminal Primer
#
# [![nbviewer](https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg)](https://nbviewer.jupyter.org/github/CollaborativeRoboticsLab/foundations-of-robotics-labs/blob/master/0-primers/02-terminal-primer.ipynb)
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/CollaborativeRoboticsLab/foundations-of-robotics-labs/master?filepath=0-primers/02-terminal-primer.ipynb)
#
# ## 📚 Schedule of Notebooks
#
# Complete these notebooks in order. Each shows estimated duration.
#
# 1. 🐍 [Python Primer](01-python-primer.ipynb) - **40 min**
# 2. 💻 [Terminal Primer](02-terminal-primer.ipynb) - **30 min**
# 3. 🤖 [ROS Primer](03-ros-primer.ipynb) - **40 min**

# %% [markdown]
# ## 💻 What is a Terminal?
#
# A **terminal** is a text-based program for running commands without a GUI. **Bash** is the default shell on Linux.
#
# ```bash
# # Example: print text to the terminal
# echo "Hello, World!"
# ```

# %% [markdown]
# ## 📖 Contents
#
# 1. 🖥️ [Terminal in Jupyter](#terminal-commands-in-jupyter-notebooks)
# 2. 📂 [Common Commands](#common-terminal-commands)
# 3. 🛠️ [Programs](#command-line-programs)

# %% [markdown]
# ![Linux Comic](./docs/images/linux-comic.gif)

# %% [markdown]
# ## 🖥️ Terminal Commands In Jupyter Notebooks
#
# Jupyter Notebooks can execute commands from the command line using the `%` prefix

# %%
# Jupyter Notebooks can execute commands from the command line using the ! prefix
# an example of this is shown below
# !echo "Hello World"

# %% [markdown]
# ## 📂 Common Terminal Commands
#
# Navigate your computer with text commands instead of clicking folders.
#
# | Command | What it does |
# | --- | --- |
# | `pwd` | Show current directory |
# | `ls` | List files in directory |
# | `cd` | Change directory |
# | `mkdir` | Make new directory |
# | `touch` | Create new file |
# | `rm` | Delete file |
# | `cp` | Copy file |
# | `mv` | Move/rename file |
# | `cat` | View file contents |
# | `grep` | Search in file |
#
# ### 🎯 Try It!
#
# > 💡 **Tip:** Add `--help` to any command for details (e.g., `ls --help`)

# %%
# The % prefix is used to execute special commands in the shell from a notebook

# what is the current working directory
# %pwd

# %%
# list all files in the current directory
# %ls

# %%
# list all files in the current directory in long format
# %ls -l # the -l is a flag that is passed to the ls command is an option that changes the output of the command

# %% [markdown]
# ## Questions
#
# Check your understanding by answering the following questions:
#
# > **Attention!**
# >
# > **These questions are not graded. They are intended to help you check your understanding of the material.**

# %% [markdown]
# #### ***Open a terminal in Jupyter and try running some of the commands listed in the table above.***
#
# **💡 Hint:** Select the terminal pane in Jupyter
#
# <img src="./docs/images/notebook-panes.png" width="450">

# %% [markdown]
# #### 1. Where are you in the file system?
#
# ```bash
# # Use the pwd command to print the current working directory
# pwd
# ```

# %% [markdown]
# #### 2. What files are in the current directory?
#
# ```bash
# # Use the ls command to list the contents of the current directory
# ls
# ```

# %% [markdown]
# #### 3. What is the hostname of your computer?
#
# ```bash
# # read the contents of the /etc/hostname file
# cat /etc/hostname
# ```

# %% [markdown]
# ## Command Line Programs
#
# A command line program is a program that runs in a terminal. It is a program that can be run from the command line. There are many builtin command line programs, and you can also install your own command line programs.
#
# Examples of command line programs that are installed by developers:
#
# - `git` - a version control system
# - `Python` - a programming language
# - `pip` - a package manager for Python
# - `ros2` - the Robot Operating System (ROS) command line interface

# %% [markdown]
# ---

# %% [markdown]
# ## 📚 Additional Resources
#
# There are many resources available online for learning how to use the terminal. Here are a few that we recommend:
#
# - [The Command Line Crash Course](<https://cglab.ca/~morin/teaching/1405/clcc/book/cli-crash-course.html>)
# - [The Linux Command Line](http://linuxcommand.org/tlcl.php)
# - [Bash Guide for Beginners](http://tldp.org/LDP/Bash-Beginners-Guide/html/index.html)
# - [Bash Reference Manual](https://www.gnu.org/software/bash/manual/bash.html)
