# %% [markdown]
# # Python Primer
#
# ## 📚 Schedule of Notebooks
#
# Complete these notebooks in order. Each shows estimated duration.
#
# 1. 🐍 [Python Primer](01-python-primer.ipynb) - **40 min**
# 2. 💻 [Terminal Primer](02-terminal-primer.ipynb) - **30 min**
# 3. 🤖 [ROS Primer](03-ros-primer.ipynb) - **40 min**
#
# A quick overview of `Python` syntax and features used in this course.
#
# [![Python Logo](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)](https://www.python.org/)

# %% [markdown]
# ## 📖 Contents
#
# > ⚡ **Tip:** Keep this notebook handy as a reference for Python syntax!
#
# 1. 📦 [Data Types](#data-types)
# 2. 📦 [Containers](#containers)
# 3. 🔄 [Program Flow](#program-flow)
# 4. ⚙️ [Operators](#operators)
# 5. 🔧 [Functions](#functions)
# 6. 🏗️ [Classes](#classes)
# 7. 📦 [Modules](#modules)
# 8. ⚠️ [Exceptions](#exceptions)

# %% [markdown]
# ![Code Comic](./docs/images/code-comic.gif)

# %% [markdown]
# ### 📦 Data Types
#
# A data type tells Python how to store and use data. Python automatically assigns types when you create variables.
#
# **Common types:**
# - `int`: whole numbers
# - `float`: decimal numbers
# - `str`: text
# - `bool`: True or False
# - `list`: ordered items
# - `tuple`: ordered, unchangeable items
# - `dict`: key-value pairs
# - `set`: unique items
# - `None`: represents nothing

# %% [markdown]
# ## 🎯 Try It!
#
# Run the cells below to see `Python` data types in action.
#
# > 💡 If you get errors, restart the kernel: Kernel → Restart

# %%
# Here are some examples of types in Python
# The type() function returns the type of the object passed to it

# Integers
# integers are whole numbers
var = 2
print("var is an integer")
print("the value of var is:")
print(var)
print("the type of var is:")
print(type(var)) # <class 'int'>

# %%
# Floats
# floats are decimal numbers
print("var is now a float")
var = 1.0
print(var)
print(type(1.0))  # <class 'float'>

# %%
# Strings
# strings are sequences of characters
var = "var is a string"
print(var)
print(type(var))  # <class 'str'>

# %%
# bool
# booleans are true or false
var = True
print("var is now boolean")
print(var)
print(type(var))  # <class 'bool'>

# %% [markdown]
# ### 📦 Containers
#
# Containers hold multiple items. Here are the main types:
#
# - **Lists** - Ordered, changeable. Use `[]`
# - **Tuples** - Ordered, unchangeable. Use `()`
# - **Dicts** - Key-value pairs. Use `{}`
# - **Sets** - Unique items. Use `{}`
#
# > **Useful list methods:**
# > - `append()`: add item
# > - `remove()`: remove item
# > - `pop()`: remove by position

# %%
# some examples of container types

# Lists
# lists are sequences of elements
var = [1,2,3,4]
print("var is now a list")
print(var)
print(type(var)) # <class 'list'>

# you can access elements of a list by index
print("the first element of var is:")
print(var[0]) # 1

# you can also access elements of a list by index from the end
print("the last element of var is:")
print(var[-1]) # 4

# %%
# Dictionaries
# dictionaries are a key-value store
var = {
    "key1": "value1",
    "key2": "value2"
}

# you can access values in a dictionary by key
print("var is now a dictionary")
print(var)
print(type(var))  # <class 'dict'>

print("the value of key1 is:")
print(var["key1"])  # value1

# dictionaries can contain any type of value including other dictionaries!
var = {
    "key1": "value1",
    "key2": { # here a dictionary is a value inside a dictionary. This is called nesting
        "key3": 3
    }
}

print("the value of key3 is:")
print(var["key2"]["key3"])  # value = 3
print(type(var["key2"]))  # <class 'dict'>

# %% [markdown]
# ### 🔄 Program Flow
#
# Control how code runs with conditions and loops.
#
# **Conditionals** - Run code based on true/false:
# - `if`: check condition
# - `elif`: check another condition
# - `else`: default action
#
# **Loops** - Repeat code:
# - `for`: loop through items
# - `while`: loop while condition is true

# %%
# some examples of control flow

# if statements
var = 1
if var == 1:
    print("var is 1")

# this will not print because var is not 2
if var == 2:
    print("var is 2")

# if-else statements
if var == 2:
    print("var is 2")
else:
    print("var is not 2")

# %% [markdown]
# **Loops** repeat code multiple times. Use `for` to go through items or `while` to repeat while a condition is true.

# %%
# Loops
# for loops
# this will print 0,1,2,3,4
print("printing numbers 0-4")
for i in range(5):
    print(i)

# while loops
var = 0
print("printing numbers 0-4 with a while loop")
while var < 5:
    print(var)
    print("var is less than 5")
    var += 1

# %% [markdown]
# ### ⚙️ Operators
#
# **Math:** `+` `-` `*` `/` `**` (power)
#
# **Assign:** `=` `+=` `-=` `*=`
#
# **Compare:** `==` `!=` `<` `<=` `>` `>=` (return True/False)
#
# **Logic:** `and` `or` `not` (return True/False)

# %%
# the following operations are arithmetic
# addition
print("addition 1+1 = ")
print(1 + 1) # 2

# subtraction
print("subtraction 1-1 = ")
print(1 - 1) # 0

# multiplication
print("multiplication 2*2 = ")
print(2 * 2) # 4

# division
print("division 4/2 = ")
print(4 / 2) # 2.0

# floor division
# floor division returns the quotient of the division rounded down to the nearest integer
print("floor division 4//2 = ")
print(4 // 2) # 2

# exponentiation
print("exponentiation 2**2 = ")
print(2 ** 2) # 4

# %%
# the following operations are assignment operations
# assignment operations assign a value to a variable

# assignment
a = 42 # a is now an integer with the value 42
print("a is assigned the value:", a)

# addition assignment
# this is the same as a = a + 1
a += 1 # a is now 43
print("after addition assignment, a is now:", a)

# subtraction assignment
# this is the same as a = a - 1
a -= 1 # a is now 42
print("after subtraction assignment, a is now:", a)

# multiplication assignment
# this is the same as a = a * 2
a *= 2 # a is now 84
print("after multiplication assignment, a is now:", a)

# division assignment
# this is the same as a = a / 2
a /= 2 # a is now 42
print("after division assignment, a is now:", a)

# %%
# the following operations are comparison operators

# equality
print("equality 1 == 1 = ")
print(1 == 1) # True

# inequality
print("inequality 1 != 1 = ")
print(1 != 1) # False

# greater than
print("greater than 2 > 1 = ")
print(2 > 1) # True

# less than
print("less than 1 < 2 = ")
print(1 < 2) # True

# %%
# the following operations are logical operators

# and
print("True and False = ")
print(True and False) # False

# or
print("True or False = ")
print(True or False) # True

# not
print("not True = ")
print(not True) # False

# %% [markdown]
# ### 🔧 Functions
#
# Group code with a name using `def`. Functions can take inputs and return outputs.

# %%
# here is a function that takes a number and returns the square of that number

# the 'def' keyword is used to define a function
# the 'x' in parentheses is the parameter.
# This is the value that will be passed to the function.
# Be careful with passing parameters in python - it is pass by reference, not pass by value.
# Also, because of dynamic typing the function can change the value or type of the parameter.
# and the
def square(x):
    # the * operator is used for multiplication
    # the 'return' keyword is used to return a value from a function
    return x * x

# let's test it out
print("using a function: square(2) = ")
print(square(2)) # 4

# functions can be chained together like this
# beware of type errors: the return type of the inner function must match the parameter type of the outer function
print("using a function: square(square(2)) = ")
print(square(square(2))) # 16

# %% [markdown]
# ### 🏗️ Classes
#
# Classes are blueprints for creating objects with data (attributes) and actions (methods).
#
# > 🤖 **Note:** ROS and robotics software heavily use classes to organize robot control and data.

# %%
# an example class
class Example:
    # the __init__ function is called when an instance of the class is created
    # the 'self' parameter is a reference to the instance of the class
    def __init__(self):
        # this is an instance variable
        self.var = 1

    # this is an instance method
    def get_var(self):
        return self.var # accessing the instance variable using self - a reference to the instance of the class


# let's create an instance of the class
example = Example()

# let's call the instance method
print("example.get_var() = ")
print(example.get_var()) # 1

# let's change the instance variable
example.var = 2

# let's call the instance method again
print("example.get_var() = ")
print(example.get_var()) # 2

# an example of inheritance
# this class inherits from the Example class
class Example2(Example):
    # the __init__ function is called when an instance of the class is created
    # the 'self' parameter is a reference to the instance of the class
    def __init__(self):
        # call the __init__ function of the parent class
        super().__init__()

        # this is an instance variable
        self.var2 = 2

    # this is an instance method
    def get_var2(self):
        return self.var2 # accessing the instance variable using self - a reference to the instance of the class


# let's create an instance of the class
example2 = Example2()

# let's call the instance method
print("example2.get_var() = ") # this method is inherited from the parent class
print(example2.get_var()) # 1

# let's call the instance method
print("example2.get_var2() = ")
print(example2.get_var2()) # 2

# %% [markdown]
# ---
# ## ✅ Self-Check Questions
#
# Test your understanding. Run exercises and use `grader.check()` to verify.
#
# > 📝 **Note:** These are practice questions to check your progress.

# %%
# Otter-Grader initialization (interactive self-checks)
import otter
grader = otter.Notebook()

# %% [markdown]
# ### Q1. is_even
# Implement a function `is_even(n: int) -> bool` that returns `True` for even numbers and `False` otherwise.

# %%
# TODO: implement is_even
def is_even(n: int) -> bool:
    # return True if n is even, else False
    pass

# %%
grader.check("q_is_even")

# %% [markdown]
# ### Q2. reverse_string
# Write a function `reverse_string(s: str) -> str` that returns the reverse of the string.

# %%
# TODO: implement reverse_string
def reverse_string(s: str) -> str:
    pass

# %%
grader.check("q_reverse_string")

# %% [markdown]
# ### Q3. merge_dicts
# Write a function `merge_dicts(a: dict, b: dict) -> dict` that returns a new dict containing all keys from `a` and `b`, with `b`'s values taking precedence when keys overlap.

# %%
# TODO: implement merge_dicts
def merge_dicts(a: dict, b: dict) -> dict:
    pass

# %%
grader.check("q_merge_dicts")

# %% [markdown]
# ### Q4. List Comprehension
# Create variables `nums = [0, 1, 2, 3, 4, 5]` and `squares` that is a list of each element squared using a list comprehension.

# %%
# TODO: define nums and squares
# nums = ...
# squares = ...

# %%
grader.check("q_squares_list")

# %% [markdown]
# ### Q5. Counter Class
# Create a class `Counter` with:
# - attribute `value` (default 0)
# - method `inc(by=1)` to increase value
# - method `reset()` to set value back to 0.

# %%
# TODO: implement Counter
class Counter:
    def __init__(self):
        pass
    def inc(self, by: int = 1):
        pass
    def reset(self):
        pass

# %%
grader.check("q_counter")

# %% [markdown]
# ---

# %% [markdown]
# ## 📚 Further Reading
#
# - [Python Docs](https://docs.python.org/3/tutorial/)
# - [W3 Schools Python](https://www.w3schools.com/python/)
# - [Learn Python with Jupyter](https://www.learnpythonwithjupyter.com/)
# - [More Examples](https://mybinder.org/v2/gist/kenjyco/69eeb503125035f21a9d/HEAD?filepath=learning-python3.ipynb)
